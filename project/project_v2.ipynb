# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.activations import linear, relu, sigmoid
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %matplotlib widget
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('./deeplearning.mplstyle')

import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

np.set_printoptions(precision=2)

# %% [markdown]
# Preprocessing of the data
# First we drop the unused data, or NA values
# Then we convert the genres into numerical values so it can be used by the machine learning algorithm

# %%
#load data, drop unnecessary columns, and drop all NA values
df = pd.read_csv('music_genre.csv')
df = df.drop(['instance_id', 'artist_name', 'track_name', 'key', 'mode','obtained_date','tempo'], axis=1) 
df = df.dropna()
df = df.sample(frac=1)

# %%
print(df.dtypes)
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# valence             float64
# music_genre          object
# dtype: object

# %%
#since music_genre is of type "object" we can't apply the neural network to it, we need to encode it into, int this case, an integers
encoder = LabelEncoder()
df['music_genre'] = encoder.fit_transform(df['music_genre'])

print(df.dtypes)
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# valence             float64
# music_genre           int64
# dtype: object

# %%
X = df.drop('music_genre', axis=1)
Y = df['music_genre']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
scaler = StandardScaler()
size = X_train.shape[1]

# %%
# UNQ_C3
# GRADED CELL: model
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.random.set_seed(1234)
model = Sequential(
    [
        ### START CODE HERE ### 
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax'),
        
        
        ### END CODE HERE ### 

    ], name="Complex"
)
model.compile(
    ### START CODE HERE ### 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = tf.keras.optimizers.Adam(),
    metrics=['accuracy']

    ### END CODE HERE ### 
)

# %%
train_2 = model.fit(X_train , Y_train , validation_data=(X_test,Y_test),epochs=100)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.2014 - accuracy: 0.1380 - val_loss: 2.2068 - val_accuracy: 0.1376
# Epoch 2/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1999 - accuracy: 0.1381 - val_loss: 2.1978 - val_accuracy: 0.1394
# Epoch 3/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1994 - accuracy: 0.1383 - val_loss: 2.1970 - val_accuracy: 0.1419
# Epoch 4/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1984 - accuracy: 0.1404 - val_loss: 2.1986 - val_accuracy: 0.1392
# Epoch 5/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.0591 - accuracy: 0.1389 - val_loss: 2.1997 - val_accuracy: 0.1397
# Epoch 6/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2489 - accuracy: 0.1401 - val_loss: 2.1936 - val_accuracy: 0.1420
# Epoch 7/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1961 - accuracy: 0.1406 - val_loss: 2.2005 - val_accuracy: 0.1395
# Epoch 8/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1955 - accuracy: 0.1394 - val_loss: 2.1928 - val_accuracy: 0.1443
# Epoch 9/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1954 - accuracy: 0.1414 - val_loss: 2.1921 - val_accuracy: 0.1457
# Epoch 10/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.8771 - accuracy: 0.1408 - val_loss: 2.1948 - val_accuracy: 0.1386
# Epoch 11/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1944 - accuracy: 0.1431 - val_loss: 2.1913 - val_accuracy: 0.1417
# Epoch 12/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1935 - accuracy: 0.1408 - val_loss: 2.1951 - val_accuracy: 0.1402
# Epoch 13/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.2809 - accuracy: 0.1416 - val_loss: 2.1925 - val_accuracy: 0.1425
# Epoch 14/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1958 - accuracy: 0.1408 - val_loss: 2.1921 - val_accuracy: 0.1415
# Epoch 15/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 3.0035 - accuracy: 0.1409 - val_loss: 2.1930 - val_accuracy: 0.1406
# Epoch 16/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1916 - accuracy: 0.1426 - val_loss: 2.1926 - val_accuracy: 0.1424
# Epoch 17/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.2593 - accuracy: 0.1421 - val_loss: 2.1994 - val_accuracy: 0.1383
# Epoch 18/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1960 - accuracy: 0.1427 - val_loss: 2.1939 - val_accuracy: 0.1413
# Epoch 19/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.3145 - accuracy: 0.1416 - val_loss: 2.1927 - val_accuracy: 0.1413
# Epoch 20/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.2983 - accuracy: 0.1426 - val_loss: 2.1917 - val_accuracy: 0.1418
# Epoch 21/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.6340 - accuracy: 0.1454 - val_loss: 2.1892 - val_accuracy: 0.1416
# Epoch 22/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2923 - accuracy: 0.1437 - val_loss: 2.1966 - val_accuracy: 0.1417
# Epoch 23/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2397 - accuracy: 0.1446 - val_loss: 2.1901 - val_accuracy: 0.1435
# Epoch 24/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.1877 - accuracy: 0.1433 - val_loss: 2.1922 - val_accuracy: 0.1470
# Epoch 25/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1880 - accuracy: 0.1434 - val_loss: 2.1928 - val_accuracy: 0.1418
# Epoch 26/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.1874 - accuracy: 0.1440 - val_loss: 2.1929 - val_accuracy: 0.1455
# Epoch 27/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1868 - accuracy: 0.1447 - val_loss: 2.1919 - val_accuracy: 0.1436
# Epoch 28/100
# 1250/1250 [==============================] - 3s 3ms/step - loss: 2.1871 - accuracy: 0.1450 - val_loss: 2.1904 - val_accuracy: 0.1418
# Epoch 29/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1866 - accuracy: 0.1423 - val_loss: 2.1988 - val_accuracy: 0.1409
# Epoch 30/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1864 - accuracy: 0.1436 - val_loss: 2.1919 - val_accuracy: 0.1436
# Epoch 31/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2094 - accuracy: 0.1438 - val_loss: 2.1894 - val_accuracy: 0.1446
# Epoch 32/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.1854 - accuracy: 0.1428 - val_loss: 2.1928 - val_accuracy: 0.1430
# Epoch 33/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1851 - accuracy: 0.1446 - val_loss: 2.1898 - val_accuracy: 0.1427
# Epoch 34/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.5560 - accuracy: 0.1444 - val_loss: 2.1948 - val_accuracy: 0.1413
# Epoch 35/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.2252 - accuracy: 0.1444 - val_loss: 2.1929 - val_accuracy: 0.1431
# Epoch 36/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.4011 - accuracy: 0.1433 - val_loss: 2.1925 - val_accuracy: 0.1430
# Epoch 37/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1842 - accuracy: 0.1445 - val_loss: 2.1900 - val_accuracy: 0.1427
# Epoch 38/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1849 - accuracy: 0.1432 - val_loss: 2.1879 - val_accuracy: 0.1445
# Epoch 39/100
# 1250/1250 [==============================] - 3s 3ms/step - loss: 3.0315 - accuracy: 0.1449 - val_loss: 2.1875 - val_accuracy: 0.1426
# Epoch 40/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1833 - accuracy: 0.1450 - val_loss: 2.2004 - val_accuracy: 0.1419
# Epoch 41/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.3397 - accuracy: 0.1450 - val_loss: 2.1919 - val_accuracy: 0.1435
# Epoch 42/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 2.1835 - accuracy: 0.1419 - val_loss: 2.1888 - val_accuracy: 0.1433
# Epoch 43/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1825 - accuracy: 0.1448 - val_loss: 2.2014 - val_accuracy: 0.1423
# Epoch 44/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.2897 - accuracy: 0.1462 - val_loss: 2.1943 - val_accuracy: 0.1433
# Epoch 45/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1824 - accuracy: 0.1439 - val_loss: 2.1929 - val_accuracy: 0.1424
# Epoch 46/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1820 - accuracy: 0.1453 - val_loss: 2.1941 - val_accuracy: 0.1414
# Epoch 47/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1813 - accuracy: 0.1480 - val_loss: 2.1931 - val_accuracy: 0.1416
# Epoch 48/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.0127 - accuracy: 0.1447 - val_loss: 2.1914 - val_accuracy: 0.1476
# Epoch 49/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1811 - accuracy: 0.1448 - val_loss: 2.1937 - val_accuracy: 0.1419
# Epoch 50/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1813 - accuracy: 0.1440 - val_loss: 2.1959 - val_accuracy: 0.1452
# Epoch 51/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1797 - accuracy: 0.1434 - val_loss: 2.1967 - val_accuracy: 0.1414
# Epoch 52/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.5336 - accuracy: 0.1454 - val_loss: 2.1936 - val_accuracy: 0.1428
# Epoch 53/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1800 - accuracy: 0.1470 - val_loss: 2.1978 - val_accuracy: 0.1429
# Epoch 54/100
# 1250/1250 [==============================] - 3s 2ms/step - loss: 4.1872 - accuracy: 0.1470 - val_loss: 2.1963 - val_accuracy: 0.1442
# Epoch 55/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2353 - accuracy: 0.1464 - val_loss: 2.1954 - val_accuracy: 0.1422
# Epoch 56/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1781 - accuracy: 0.1469 - val_loss: 2.1939 - val_accuracy: 0.1452
# Epoch 57/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1798 - accuracy: 0.1455 - val_loss: 2.1990 - val_accuracy: 0.1419
# Epoch 58/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1953 - accuracy: 0.1472 - val_loss: 2.1954 - val_accuracy: 0.1451
# Epoch 59/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2241 - accuracy: 0.1464 - val_loss: 2.1917 - val_accuracy: 0.1419
# Epoch 60/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2210 - accuracy: 0.1445 - val_loss: 2.1933 - val_accuracy: 0.1423
# Epoch 61/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1779 - accuracy: 0.1476 - val_loss: 2.2040 - val_accuracy: 0.1417
# Epoch 62/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1880 - accuracy: 0.1452 - val_loss: 2.2026 - val_accuracy: 0.1407
# Epoch 63/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.3280 - accuracy: 0.1461 - val_loss: 2.1968 - val_accuracy: 0.1416
# Epoch 64/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1794 - accuracy: 0.1462 - val_loss: 2.1980 - val_accuracy: 0.1420
# Epoch 65/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1773 - accuracy: 0.1469 - val_loss: 2.1979 - val_accuracy: 0.1421
# Epoch 66/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1757 - accuracy: 0.1478 - val_loss: 2.1949 - val_accuracy: 0.1431
# Epoch 67/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1761 - accuracy: 0.1497 - val_loss: 2.1995 - val_accuracy: 0.1404
# Epoch 68/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 5.0509 - accuracy: 0.1491 - val_loss: 2.2006 - val_accuracy: 0.1449
# Epoch 69/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1750 - accuracy: 0.1478 - val_loss: 2.1962 - val_accuracy: 0.1427
# Epoch 70/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.6362 - accuracy: 0.1496 - val_loss: 2.1927 - val_accuracy: 0.1456
# Epoch 71/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.0130 - accuracy: 0.1481 - val_loss: 2.1969 - val_accuracy: 0.1444
# Epoch 72/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1747 - accuracy: 0.1456 - val_loss: 2.2060 - val_accuracy: 0.1404
# Epoch 73/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1744 - accuracy: 0.1494 - val_loss: 2.2029 - val_accuracy: 0.1435
# Epoch 74/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1747 - accuracy: 0.1479 - val_loss: 2.1982 - val_accuracy: 0.1445
# Epoch 75/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1735 - accuracy: 0.1507 - val_loss: 2.1977 - val_accuracy: 0.1418
# Epoch 76/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1744 - accuracy: 0.1491 - val_loss: 2.2074 - val_accuracy: 0.1421
# Epoch 77/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1742 - accuracy: 0.1486 - val_loss: 2.2042 - val_accuracy: 0.1401
# Epoch 78/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1737 - accuracy: 0.1470 - val_loss: 2.2053 - val_accuracy: 0.1422
# Epoch 79/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1728 - accuracy: 0.1469 - val_loss: 2.2043 - val_accuracy: 0.1427
# Epoch 80/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.4559 - accuracy: 0.1466 - val_loss: 2.2064 - val_accuracy: 0.1427
# Epoch 81/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.7135 - accuracy: 0.1487 - val_loss: 2.2094 - val_accuracy: 0.1403
# Epoch 82/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2268 - accuracy: 0.1493 - val_loss: 2.2065 - val_accuracy: 0.1407
# Epoch 83/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.3260 - accuracy: 0.1485 - val_loss: 2.2015 - val_accuracy: 0.1432
# Epoch 84/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 3.7385 - accuracy: 0.1478 - val_loss: 2.2052 - val_accuracy: 0.1418
# Epoch 85/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1708 - accuracy: 0.1490 - val_loss: 2.2151 - val_accuracy: 0.1437
# Epoch 86/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1706 - accuracy: 0.1496 - val_loss: 2.2127 - val_accuracy: 0.1428
# Epoch 87/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1710 - accuracy: 0.1488 - val_loss: 2.2145 - val_accuracy: 0.1426
# Epoch 88/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1701 - accuracy: 0.1513 - val_loss: 2.2154 - val_accuracy: 0.1412
# Epoch 89/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1700 - accuracy: 0.1496 - val_loss: 2.2175 - val_accuracy: 0.1454
# Epoch 90/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2762 - accuracy: 0.1485 - val_loss: 2.2179 - val_accuracy: 0.1419
# Epoch 91/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.6089 - accuracy: 0.1496 - val_loss: 2.2247 - val_accuracy: 0.1423
# Epoch 92/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1713 - accuracy: 0.1495 - val_loss: 2.2012 - val_accuracy: 0.1455
# Epoch 93/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.6113 - accuracy: 0.1507 - val_loss: 2.2060 - val_accuracy: 0.1478
# Epoch 94/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2063 - accuracy: 0.1503 - val_loss: 2.2034 - val_accuracy: 0.1420
# Epoch 95/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1683 - accuracy: 0.1491 - val_loss: 2.2173 - val_accuracy: 0.1406
# Epoch 96/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.2092 - accuracy: 0.1490 - val_loss: 2.2193 - val_accuracy: 0.1403
# Epoch 97/100
# 1250/1250 [==============================] - 2s 1ms/step - loss: 2.1688 - accuracy: 0.1512 - val_loss: 2.2036 - val_accuracy: 0.1430
# Epoch 98/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1679 - accuracy: 0.1484 - val_loss: 2.2050 - val_accuracy: 0.1423
# Epoch 99/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1674 - accuracy: 0.1508 - val_loss: 2.2195 - val_accuracy: 0.1395
# Epoch 100/100
# 1250/1250 [==============================] - 2s 2ms/step - loss: 2.1678 - accuracy: 0.1501 - val_loss: 2.2163 - val_accuracy: 0.1427
